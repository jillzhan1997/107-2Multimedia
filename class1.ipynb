# %% [markdown]
# <a href="https://colab.research.google.com/github/jillzhan1997/107-2Multimedia/blob/master/class1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
import cv2

# %%
image=cv2.imread('dog.jpg',cv2.IMREAD_ANYCOLOR)

# %%
image=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

# %%
from matplotlib import pyplot as plt

# %%
plt.imshow(image)

# %%
image.shape
# Out:
# (267, 400, 3)

# %%
# !pwd
# Out:
# /Users/janice
